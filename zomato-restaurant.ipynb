# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings("ignore")

# %%
import os

folder_path = r"C:\Users\gaunt\Downloads\archive"
print(os.listdir(folder_path))
# Out:
# ['Country-Code.xlsx', 'file1.json', 'file2.json', 'file3.json', 'file4.json', 'file5.json', 'zomato.csv']

# %%
df = pd.read_csv(r"C:\Users\gaunt\Downloads\archive\zomato.csv", encoding="latin1")

# %%
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
# Basic information
# check the size of rows and column of the dataset
print(f"your rows are {df.shape[0]} and your column are {df.shape[1]}")
# Out:
# your rows are 9551 and your column are 21

# %%
# now let's see how many column have null values in total
df.isna()
df.isna().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
# which city has the highest number of restanurant .
city_count = df["City"].value_counts().head(10)
city_count
# Out:
# City
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
# Bhubaneshwar      21
# Amritsar          21
# Ahmedabad         21
# Lucknow           21
# Guwahati          21
# Name: count, dtype: int64

# %%
# Using barplot city count
sns.barplot(x = city_count.values, y = city_count.index)
plt.title("Top cities with most restanurant")
# Out:
# Text(0.5, 1.0, 'Top cities with most restanurant')

# %%
# write a Python program to count how many times each restaurant name appears in the dataset.
df["Restaurant Name"].value_counts()
# Out:
# Restaurant Name
# Cafe Coffee Day             83
# Domino's Pizza              79
# Subway                      63
# Green Chick Chop            51
# McDonald's                  48
#                             ..
# Odeon Social                 1
# Johnny Rockets               1
# House of Commons             1
# HotMess                      1
# Walter's Coffee Roastery     1
# Name: count, Length: 7446, dtype: int64

# %%
# Write a Python Pandas program to find the top 10 most frequent restaurant names in the dataset
Restaurant_name = df["Restaurant Name"].value_counts().head(10)
Restaurant_name
# Out:
# Restaurant Name
# Cafe Coffee Day     83
# Domino's Pizza      79
# Subway              63
# Green Chick Chop    51
# McDonald's          48
# Keventers           34
# Pizza Hut           30
# Giani               29
# Baskin Robbins      28
# Barbeque Nation     26
# Name: count, dtype: int64

# %%
# Write a Python program using Pandas and Seaborn to find the top 10 most frequent restaurant
# names in the dataset and visualize them using a bar plot.

sns.barplot(x = Restaurant_name.values, y = Restaurant_name.index)
plt.title("Top 10 Restaurant")
plt.xlabel("Number OF Restaurant")
plt.ylabel("Name OF Restaurant")
# Out:
# Text(0, 0.5, 'Name OF Restaurant')

# %%
plt.figure(figsize = (10,6))
sns.barplot(x = Restaurant_name.values, y = Restaurant_name.index)
plt.title("Top 10 Restaurant")
plt.xlabel("Number OF Restaurant")
plt.ylabel("Name OF Restaurant")
# Out:
# Text(0, 0.5, 'Name OF Restaurant')

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
# Write a Python program using Seaborn to visualize the count of each 
# rating category from the "Rating text" column in the dataset.
sns.countplot(x = df["Rating text"])
# Out:
# <Axes: xlabel='Rating text', ylabel='count'>

# %%
sns.countplot(x = df["Rating color"])
# Out:
# <Axes: xlabel='Rating color', ylabel='count'>

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
# How many restaurants provide online delivery
df["Has Online delivery"].value_counts()
# Out:
# Has Online delivery
# No     7100
# Yes    2451
# Name: count, dtype: int64

# %%
# How many restaurants offer online delivery
sns.countplot(x=df["Has Online delivery"])
plt.title("Online Delivery Availability")
# Out:
# Text(0.5, 1.0, 'Online Delivery Availability')

# %%
# which price range category has the most restanurants.
sns.countplot(x = df["Price range"])
# Out:
# <Axes: xlabel='Price range', ylabel='count'>

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
# Find the average rating of restaurants in each city.
avg_rating = df.groupby("City")["Aggregate rating"].mean().sort_values(ascending=False)
avg_rating
avg_rating.head(10)
# Out:
# City
# Inner City          4.900000
# Quezon City         4.800000
# Makati City         4.650000
# Pasig City          4.633333
# Mandaluyong City    4.625000
# Beechworth          4.600000
# London              4.535000
# Taguig City         4.525000
# Tagaytay City       4.500000
# Secunderabad        4.500000
# Name: Aggregate rating, dtype: float64

# %%
# Find the total number of votes for each city.
city_votes = df.groupby("City")["Votes"].sum().sort_values(ascending=False)
city_votes.head(10)
# Out:
# City
# New Delhi    628340
# Gurgaon      132160
# Noida         73488
# Bangalore     56115
# Kolkata       44593
# Mumbai        29697
# Chennai       27695
# Tampa Bay     27407
# Hyderabad     24135
# Orlando       23989
# Name: Votes, dtype: int64

# %%
top_cities = city_votes.head(10)

sns.barplot(x=top_cities.values, y=top_cities.index)

plt.title("Top 10 Cities by Total Votes")
plt.xlabel("Total Votes")
plt.ylabel("City")

plt.show()

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
# Find the average cost for two people in each city.
avg_cost = df.groupby("City")["Average Cost for two"].mean().sort_values(ascending=False)

avg_cost.head(10)
# Out:
# City
# Jakarta             308437.500000
# Tangerang           250000.000000
# Bogor               160000.000000
# Bandung             150000.000000
# Pasay City            3333.333333
# Colombo               2375.000000
# Mandaluyong City      2000.000000
# Panchkula             2000.000000
# Taguig City           1725.000000
# Hyderabad             1361.111111
# Name: Average Cost for two, dtype: float64

# %%
# Find the number of restaurants in each price range.
price_range_count = df.groupby("Price range").size()

price_range_count
# Out:
# Price range
# 1    4444
# 2    3113
# 3    1408
# 4     586
# dtype: int64

# %%
# Find the number of restaurants for each rating category (Rating text)
rating_count = df.groupby("Rating text").size()

rating_count
# Out:
# Rating text
# Average      3737
# Excellent     301
# Good         2100
# Not rated    2148
# Poor          186
# Very Good    1079
# dtype: int64

# %%
# Find the top 10 restaurants with the highest number of votes
top_votes = df.sort_values(by="Votes", ascending=False)

top_votes[["Restaurant Name", "City", "Votes"]].head(10)
# Out:
#                 Restaurant Name       City  Votes
# 728                        Toit  Bangalore  10934
# 735                    Truffles  Bangalore   9667
# 3994           Hauz Khas Social  New Delhi   7931
# 2412                  Peter Cat    Kolkata   7574
# 739   AB's - Absolute Barbecues  Bangalore   6907
# 2414            Barbeque Nation    Kolkata   5966
# 743                 Big Brewsky  Bangalore   5705
# 2307  AB's - Absolute Barbecues  Hyderabad   5434
# 736             The Black Pearl  Bangalore   5385
# 2411                      BarBQ    Kolkata   5288

# %%
# Find the top 10 cities with the highest average ratings.
city_rating = df.groupby("City")["Aggregate rating"].mean().sort_values(ascending=False)

city_rating.head(10)
# Out:
# City
# Inner City          4.900000
# Quezon City         4.800000
# Makati City         4.650000
# Pasig City          4.633333
# Mandaluyong City    4.625000
# Beechworth          4.600000
# London              4.535000
# Taguig City         4.525000
# Tagaytay City       4.500000
# Secunderabad        4.500000
# Name: Aggregate rating, dtype: float64

# %%
top_city_rating = city_rating.head(10)

sns.barplot(x=top_city_rating.values, y=top_city_rating.index)

plt.title("Top 10 Cities with Highest Average Ratings")
plt.xlabel("Average Rating")
plt.ylabel("City")
# Out:
# Text(0, 0.5, 'City')

# %%
# Find the most expensive restaurants based on the average cost for two.
expensive_restaurants = df.sort_values(by="Average Cost for two", ascending=False)

expensive_restaurants[["Restaurant Name", "City", "Average Cost for two"]].head(10)
# Out:
#                   Restaurant Name       City  Average Cost for two
# 9284     Satoo - Hotel Shangri-La    Jakarta                800000
# 9283                         Skye    Jakarta                800000
# 9287                   Sushi Masa    Jakarta                500000
# 9289               3 Wise Monkeys    Jakarta                450000
# 9294  Avec Moi Restaurant and Bar    Jakarta                350000
# 9295                      Onokabe  Tangerang                300000
# 9288   Lucky Cat Coffee & Kitchen    Jakarta                300000
# 9278                   Lemongrass      Bogor                250000
# 9285                        MONKS    Jakarta                250000
# 9296             Talaga Sampireun  Tangerang                200000

# %%
# Find the least rated restaurants in the dataset
least_rated = df.sort_values(by="Aggregate rating")

least_rated[["Restaurant Name", "City", "Aggregate rating"]].head(10)
# Out:
#             Restaurant Name       City  Aggregate rating
# 6615            LSK Express  New Delhi               0.0
# 1994             Apni Rasoi    Gurgaon               0.0
# 1995  Bala Ji Sweets Corner    Gurgaon               0.0
# 1996                Barista    Gurgaon               0.0
# 1997        Biryani Express    Gurgaon               0.0
# 1998          Cafe #22hours    Gurgaon               0.0
# 1999        Cake Innovation    Gurgaon               0.0
# 2000             Chawla's_    Gurgaon               0.0
# 2001        China Gathering    Gurgaon               0.0
# 2002    Chinese Hot Express    Gurgaon               0.0

# %%
# Find the top 5 cuisines with the highest number of restaurants
df["Cuisines"].value_counts().head(5)
# Out:
# Cuisines
# North Indian             936
# North Indian, Chinese    511
# Chinese                  354
# Fast Food                354
# North Indian, Mughlai    334
# Name: count, dtype: int64

# %%
sns.barplot(x=top_cuisines.values, y=top_cuisines.index)

plt.title("Top 5 Most Popular Cuisines")
plt.xlabel("Number of Restaurants")
plt.ylabel("Cuisines")
# Out:
# Text(0, 0.5, 'Cuisines')

# %%
# Find restaurants with rating greater than 4.5
high_rating = df[df["Aggregate rating"] > 4.5]

high_rating[["Restaurant Name", "City", "Aggregate rating"]]
# Out:
#                                Restaurant Name              City  \
# 0                             Le Petit Souffle       Makati City
# 3                                         Ooma  Mandaluyong City
# 4                                  Sambo Kojin  Mandaluyong City
# 8     Spiral - Sofitel Philippine Plaza Manila        Pasay City
# 9                                     Locavore        Pasig City
# ...                                        ...               ...
# 9536                           Pizza ÛÁl Forno            Ankara
# 9537                       J'adore Chocolatier         ÛÁstanbul
# 9538                                 Starbucks         ÛÁstanbul
# 9540                          Draft Gastro Pub         ÛÁstanbul
# 9544                     Karakí_y Gí_llí_oÛôlu         ÛÁstanbul
#
#       Aggregate rating
# 0                  4.8
# 3                  4.9
# 4                  4.8
# 8                  4.9
# 9                  4.8
# ...                ...
# ...

# %%
# Find restaurants that offer both online delivery and table booking
both_services = df[(df["Has Online delivery"] == "Yes") & (df["Has Table booking"] == "Yes")]

both_services[["Restaurant Name", "City", "Has Online delivery", "Has Table booking"]]
# Out:
#                        Restaurant Name          City Has Online delivery  \
# 566                     Pizza Di Rocco     Abu Dhabi                 Yes
# 571   Cho Gao - Crowne Plaza Abu Dhabi     Abu Dhabi                 Yes
# 572                             Gazebo     Abu Dhabi                 Yes
# 578                   Indian By Nature     Abu Dhabi                 Yes
# 585                      Maharaja Bhog         Dubai                 Yes
# ...                                ...           ...                 ...
# 9166                           Chili's          Pune                 Yes
# 9168                        Blue Water          Pune                 Yes
# 9170                   Tales & Spirits          Pune                 Yes
# 9171           18 Degrees Resto Lounge          Pune                 Yes
# 9194                    Saffron Mantra  Secunderabad                 Yes
#
#      Has Table booking
# 566                Yes
# 571                Yes
# ...

# %%
# Find the most expensive restaurants (based on average cost)
expensive_restaurants = df.sort_values(by="Average Cost for two", ascending=False)

expensive_restaurants[["Restaurant Name", "City", "Average Cost for two"]].head(10)
# Out:
#                   Restaurant Name       City  Average Cost for two
# 9284     Satoo - Hotel Shangri-La    Jakarta                800000
# 9283                         Skye    Jakarta                800000
# 9287                   Sushi Masa    Jakarta                500000
# 9289               3 Wise Monkeys    Jakarta                450000
# 9294  Avec Moi Restaurant and Bar    Jakarta                350000
# 9295                      Onokabe  Tangerang                300000
# 9288   Lucky Cat Coffee & Kitchen    Jakarta                300000
# 9278                   Lemongrass      Bogor                250000
# 9285                        MONKS    Jakarta                250000
# 9296             Talaga Sampireun  Tangerang                200000

# %%
# Find restaurants with price range 4 (highest)
price_range_4 = df[df["Price range"] == 4]

price_range_4[["Restaurant Name", "City", "Price range", "Average Cost for two"]]
# Out:
#              Restaurant Name              City  Price range  \
# 2     Heat - Edsa Shangri-La  Mandaluyong City            4
# 3                       Ooma  Mandaluyong City            4
# 4                Sambo Kojin  Mandaluyong City            4
# 6                 Buffet 101        Pasay City            4
# 7                    Vikings        Pasay City            4
# ...                      ...               ...          ...
# 9525                 Cafemiz            Ankara            4
# 9526                 Nusr-Et            Ankara            4
# 9540        Draft Gastro Pub         ÛÁstanbul            4
# 9548                   Huqqa         ÛÁstanbul            4
# 9549            Aôôk Kahve         ÛÁstanbul            4
#
#       Average Cost for two
# 2                     4000
# 3                     1500
# 4                     1500
# 6                     2000
# 7                     2000
# ...                    ...
# 9525                   150
# ...

# %%
# Find restaurants located in a specific city (e.g., Delhi)
delhi_restaurants = df[df["City"] == "New Delhi"]

delhi_restaurants[["Restaurant Name", "City", "Aggregate rating", "Average Cost for two"]]
# Out:
#            Restaurant Name       City  Aggregate rating  Average Cost for two
# 2560            Food Cloud  New Delhi               0.0                   500
# 2561             Burger.in  New Delhi               3.2                   350
# 2562       Days of the Raj  New Delhi               3.4                  1500
# 2563        Dilli Ka Dhaba  New Delhi               2.6                   500
# 2564             Govardhan  New Delhi               3.4                   500
# ...                    ...        ...               ...                   ...
# 8028          Motu N Patlu  New Delhi               0.0                   250
# 8029        S.K. Fast Food  New Delhi               0.0                   350
# 8030    Sufiyan Restaurant  New Delhi               0.0                   250
# 8031       The Relax Point  New Delhi               0.0                   250
# 8032  Zareen's Dastarkhwan  New Delhi               0.0                   800
#
# [5473 rows x 4 columns]

# %%
# Find restaurants with more than 1000 votes.
high_votes = df[df["Votes"] > 1000]

high_votes[["Restaurant Name", "City", "Votes", "Aggregate rating"]]
# Out:
#             Restaurant Name          City  Votes  Aggregate rating
# 10         Silantro Fil-Mex    Pasig City   1070               4.9
# 103       Last Resort Grill        Athens   1821               4.5
# 120       Transmetropolitan        Athens   1098               4.4
# 249            Hickory Park    Des Moines   1025               4.5
# 255                  Centro    Des Moines   1109               4.5
# ...                     ...           ...    ...               ...
# 9462           The Wolfpack  Johannesburg   1024               4.1
# 9537    J'adore Chocolatier     ÛÁstanbul   1311               4.7
# 9538              Starbucks     ÛÁstanbul   1042               4.9
# 9544  Karakí_y Gí_llí_oÛôlu     ÛÁstanbul   1305               4.7
# 9547          Ceviz AÛôacÛ±     ÛÁstanbul   1034               4.2
#
# [296 rows x 4 columns]

# %%
# Create a bar plot showing the top 10 most frequent restaurant names.
top_restaurants = df["Restaurant Name"].value_counts().head(10)

sns.barplot(x=top_restaurants.values, y=top_restaurants.index)

plt.title("Top 10 Most Frequent Restaurant Names")
plt.xlabel("Number of Restaurants")
plt.ylabel("Restaurant Name")
# Out:
# Text(0, 0.5, 'Restaurant Name')

# %%
# Plot the distribution of restaurant ratings
sns.histplot(df["Aggregate rating"], bins=20)

plt.title("Distribution of Restaurant Ratings")
plt.xlabel("Rating")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
# Visualize votes vs rating using a scatter plot
sns.scatterplot(x=df["Votes"], y=df["Aggregate rating"])

plt.title("Votes vs Rating")
plt.xlabel("Votes")
plt.ylabel("Rating")
# Out:
# Text(0, 0.5, 'Rating')

# %%
# Create a pie chart of online delivery availability
online_delivery = df["Has Online delivery"].value_counts()

plt.pie(online_delivery.values, labels=online_delivery.index, autopct="%1.1f%%")

plt.title("Online Delivery Availability")
# Out:
# Text(0.5, 1.0, 'Online Delivery Availability')
